# %% [markdown]
# # Model customisation & experiments
#
# This is an alternative to running `./main.py`

# %%
# if the server isn't running already, start it
#!make -C ../ server

# %%
import os

TICK = 100 # speed of the game [milliseconds]
TETRIS_SERVER_URL = "http://localhost:8888"

# Silence the cretinous nagging of TensorFlow:
# "This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# "To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags."
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # Note: needs to be set before importing tensorflow

# in Jupyter notebooks, we need the async version of playwright
from tetris_control_async import control as ctrl
from model import Model


num_iterations = 1 # number of games to play per training session
off_policy = True # set to false to train on-policy

# %%
import numpy as np
import tensorflow as tf
    
def my_model():
    """Create custom model"""
    model = tf.keras.Sequential()

    # Comment this out so that the shape is not specified until the model is first instantiated
    # myShape = encode_state(get_state()).shape
    # model.add(tf.keras.layers.Input(input_shape=myShape))

    model.add(tf.keras.layers.Dense(256, activation='relu'))

    numOutputs = 4 * 10 # 4 rotations × 10 positions
    model.add(tf.keras.layers.Dense(numOutputs, activation='softmax'))

    # Compile the model.
    model.compile(optimizer='adam', loss='mse')

    return model

# %%
async def main():
    async with ctrl(TETRIS_SERVER_URL) as control:
        model = Model(control)
        control.set_tick(TICK)
        model.model = my_model() # override Model.model
        model.train_model(num_iterations, off_policy)

await main()
# Out:
# self.playwright: <playwright._impl._playwright.Playwright object at 0x7fbaefe75070>
# Iteration: 1/1
# Loaded weights from file autopilot-model-weights.h5
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 256)               58112
#
#  dense_9 (Dense)             (None, 40)                10280
#
# =================================================================
# Total params: 68,392
# Trainable params: 68,392
# Non-trainable params: 0
# _________________________________________________________________
# Model summary: None (None, 226) (None, 40)
# piece: L position: 7 rotation: 3 reward: -110.4 (-55.79999999999998)
# piece: J position: 0 rotation: 1 reward: -0.4 (-60.0)
# piece: J position: 1 rotation: 3 reward: 0.0 (-85.2)
# piece: O position: 4 rotation: 0 reward: 0.0 (-110.8)
# piece: S position: 7 rotation: 0 reward: -55.2 (-85.2)
# piece: L position: 5 rotation: 2 reward: 28267.471247461905 (-28323.071247461903)
# piece: L position: 7 rotation: 1 reward: -54.8 (-0.8000000000000043)
# piece: O position: 0 rotation: 0 reward: -0.4 (0.0)
# piece: O position: 2 rotation: 0 reward: 0.0 (-110.4)
# piece: I position: 4 rotation: 0 reward: 9760.2 (-9815.400000000001)
# piece: S position: 5 rotation: 0 reward: 10020.2 (-10049.800000000001)
# piece: L position: 5 rotation: 1 reward: 0.4 (-1.0)
# piece: L position: 1 rotation: 3 reward: 0.0 (-60.0)
# piece: I position: 3 rotation: 1 reward: -55.4 (-119.4)
# piece: Z position: 0 rotation: 1 reward: -0.4 (0.0)
# piece: L position: 8 rotation: 0 reward: 9870.2 (-10069.800000000001)
# piece: S position: 6 rotation: 1 reward: -110.4 (-115.0)
# piece: J position: 2 rotation: 2 reward: 0.4 (-59.6)
# piece: I position: 9 rotation: 0 reward: 9840.8 (-9930.599999999999)
# piece: T position: 0 rotation: 1 reward: 9900.4 (-10161.199999999999)
# piece: Z position: 3 rotation: 0 reward: 0.0 (-230.8)
# piece: O position: 1 rotation: 0 reward: -55.0 (-85.4)
# piece: O position: 7 rotation: 0 reward: -29.6 (-55.800000000000004)
# piece: J position: 3 rotation: 3 reward: 9900.6 (-10100.800000000001)
# piece: S position: 5 rotation: 1 reward: -110.4 (-60.0)
# piece: I position: 1 rotation: 1 reward: 0.0 (-30.0)
# piece: S position: 8 rotation: 1 reward: -0.4 (-199.79999999999998)
# piece: S position: 6 rotation: 1 reward: -54.6 (-145.6)
# piece: Z position: 0 rotation: 1 reward: 9900.2 (0.0)
# piece: I position: 2 rotation: 1 reward: -89.2 (-115.8)
# piece: J position: 7 rotation: 3 reward: 0.4 (-200.6)
# piece: J position: 0 rotation: 2 reward: 10000.2 (-10200.400000000001)
# piece: Z position: 4 rotation: 1 reward: -0.8 (-195.0)
# piece: T position: 6 rotation: 0 reward: -0.4 (-195.4)
# piece: L position: 2 rotation: 0 reward: 9870.8 (-10071.4)
# piece: T position: 3 rotation: 1 reward: -54.6 (-0.19999999999999574)
# piece: I position: 4 rotation: 1 reward: -29.6 (-115.4)
# piece: T position: 8 rotation: 3 reward: 0.2 (0.0)
# piece: Z position: 0 rotation: 0 reward: -85.0 (-55.80000000000001)
# piece: O position: 2 rotation: 0 reward: -55.4 (-0.3999999999999986)
# piece: I position: 4 rotation: 1 reward: 0.0 (-165.8)
# piece: S position: 0 rotation: 0 reward: -55.2 (0.0)
# piece: Z position: 8 rotation: 1 reward: 9961.0 (-10131.2)
# piece: L position: 4 rotation: 3 reward: -0.4 (-255.0)
# piece: S position: 7 rotation: 0 reward: 9990.0 (-10160.4)
# piece: T position: 3 rotation: 0 reward: -55.0 (-175.0)
# piece: L position: 7 rotation: 1 reward: 0.2 (-230.39999999999998)
# piece: I position: 0 rotation: 0 reward: 28179.271247461904 (0.0)
# piece: S position: 5 rotation: 1 reward: 9930.6 (-10071.4)
# piece: I position: 1 rotation: 0 reward: 9815.6 (-9961.0)
# piece: S position: 2 rotation: 0 reward: 9960.8 (-10046.599999999999)
# piece: T position: 6 rotation: 0 reward: -0.4 (-85.19999999999999)
# piece: S position: 8 rotation: 1 reward: -55.0 (0.0)
# piece: J position: 2 rotation: 2 reward: 9930.2 (-10015.400000000001)
# piece: L position: 4 rotation: 3 reward: 0.0 (0.0)
# piece: I position: 0 rotation: 0 reward: 9756.0 (0.0)
# piece: J position: 2 rotation: 3 reward: -0.4 (-41999.6)
# piece: S position: 6 rotation: 1 reward: -55.4 (0.0)
# piece: L position: 4 rotation: 2 reward: 0.8 (-230.8)
# piece: S position: 8 rotation: 1 reward: 0.0 (0.0)
# piece: J position: 1 rotation: 2 reward: 28173.871247461902 (-28403.6712474619)
# piece: I position: 3 rotation: 0 reward: 9790.2 (-51790.2)
# piece: O position: 1 rotation: 0 reward: 0.0 (-30.2)
# piece: J position: 4 rotation: 1 reward: 0.0 (-84.6)
# piece: J position: 7 rotation: 3 reward: -29.2 (-41970.8)
# piece: J position: 0 rotation: 2 reward: 9905.8 (0.0)
# piece: S position: 6 rotation: 1 reward: -0.4 (-85.39999999999999)
# piece: I position: 2 rotation: 1 reward: -29.2 (-41970.8)
# piece: I position: 0 rotation: 1 reward: -55.2 (-165.60000000000002)
# piece: J position: 7 rotation: 3 reward: 10020.4 (-10246.0)
# piece: O position: 6 rotation: 0 reward: -55.8 (-29.200000000000003)
# piece: L position: 4 rotation: 2 reward: -29.2 (-141.4)
# piece: O position: 8 rotation: 0 reward: -29.2 (0.0)
# piece: J position: 0 rotation: 1 reward: -55.4 (-115.19999999999999)
# piece: J position: 1 rotation: 3 reward: 10020.8 (-10276.4)
# piece: J position: 4 rotation: 2 reward: 9875.4 (-10101.0)
# piece: J position: 6 rotation: 3 reward: 9841.2 (-10011.800000000001)
# piece: S position: 2 rotation: 0 reward: -55.4 (0.0)
# piece: S position: 0 rotation: 0 reward: 0.2 (-0.6000000000000001)
# piece: S position: 8 rotation: 1 reward: -0.4 (0.0)
# piece: L position: 6 rotation: 0 reward: 9904.0 (-10159.4)
# piece: I position: 5 rotation: 0 reward: 9875.4 (-9985.8)
# piece: J position: 0 rotation: 2 reward: 9870.6 (-51870.6)
# piece: S position: 8 rotation: 1 reward: -0.4 (0.0)
# piece: T position: 2 rotation: 0 reward: 0.0 (-110.2)
# piece: Z position: 0 rotation: 0 reward: -85.0 (-140.4)
# piece: Z position: 1 rotation: 0 reward: -55.4 (-115.0)
# piece: O position: 4 rotation: 0 reward: -30.0 (-0.1999999999999993)
# piece: T position: 6 rotation: 3 reward: 9811.6 (-9811.800000000001)
# piece: I position: 9 rotation: 0 reward: -55.4 (-41944.6)
# piece: I position: 1 rotation: 1 reward: -30.0 (-80.4)
# piece: J position: 6 rotation: 3 reward: -28.8 (-25.999999999999996)
# piece: O position: 5 rotation: 0 reward: -55.4 (-114.6)
# piece: T position: 7 rotation: 2 reward: -29.4 (-141.2)
# piece: T position: 2 rotation: 0 reward: -55.4 (-119.6)
# piece: L position: 0 rotation: 0 reward: 9965.2 (-10140.0)
# piece: S position: 1 rotation: 0 reward: 0.0 (-85.8)
# piece: L position: 7 rotation: 1 reward: 0.2 (-140.2)
# piece: Z position: 4 rotation: 0 reward: -29.6 (-26.199999999999996)
# piece: I position: 6 rotation: 1 reward: 0.2 (-221.0)
# piece: O position: 8 rotation: 0 reward: -110.4 (-0.3999999999999915)
# piece: I position: 1 rotation: 0 reward: 9994.2 (-10169.400000000001)
# piece: S position: 3 rotation: 1 reward: 10019.2 (-10049.6)
# piece: L position: 5 rotation: 3 reward: 0.4 (-176.20000000000002)
# piece: S position: 5 rotation: 0 reward: -0.4 (-170.79999999999998)
# piece: L position: 5 rotation: 1 reward: -55.4 (-85.4)
# piece: J position: 2 rotation: 2 reward: 0.8 (-86.2)
# piece: Z position: 8 rotation: 1 reward: -84.8 (-111.39999999999999)
# piece: O position: 1 rotation: 0 reward: -0.8 (0.0)
# piece: L position: 3 rotation: 2 reward: 1.2000000000000002 (-167.39999999999998)
# piece: I position: 0 rotation: 0 reward: 51484.72422706632 (-51706.32422706632)
# piece: L position: 3 rotation: 3 reward: -55.4 (-110.79999999999998)
# piece: L position: 6 rotation: 3 reward: 0.0 (-111.2)
# piece: T position: 0 rotation: 1 reward: 9875.2 (-9931.0)
# piece: Z position: 1 rotation: 0 reward: 0.0 (0.0)
# piece: Z position: 5 rotation: 0 reward: 0.0 (-170.8)
# piece: L position: 3 rotation: 2 reward: -84.6 (-141.6)
# piece: L position: 8 rotation: 2 reward: 9810.4 (-9926.199999999999)
# piece: Z position: 4 rotation: 0 reward: -55.4 (-145.4)
# piece: O position: 0 rotation: 0 reward: -0.4 (0.0)
# piece: I position: 7 rotation: 0 reward: -55.0 (-166.6)
# piece: O position: 8 rotation: 0 reward: 0.4 (-115.80000000000001)
# piece: L position: 1 rotation: 2 reward: 9899.8 (0.0)
# piece: L position: 3 rotation: 1 reward: -29.2 (-197.0)
# piece: J position: 6 rotation: 2 reward: 9786.2 (-10012.400000000001)
# piece: L position: 0 rotation: 1 reward: 10019.6 (-10190.800000000001)
# piece: L position: 3 rotation: 1 reward: 0.8 (-227.0)
# piece: S position: 7 rotation: 1 reward: -140.4 (-0.4000000000000057)
# piece: S position: 4 rotation: 0 reward: -30.0 (-0.8000000000000007)
# piece: O position: 0 rotation: 0 reward: -0.4 (-0.4)
# piece: T position: 2 rotation: 2 reward: -29.2 (-115.8)
# piece: S position: 8 rotation: 1 reward: 10055.0 (-10195.8)
# piece: S position: 1 rotation: 1 reward: -55.4 (-60.00000000000001)
# piece: O position: 3 rotation: 0 reward: -0.4 (-140.4)
# piece: L position: 5 rotation: 2 reward: 9900.4 (-10040.8)
# piece: J position: 0 rotation: 2 reward: -54.8 (-144.8)
# piece: L position: 8 rotation: 2 reward: 9840.8 (-51840.8)
# piece: I position: 3 rotation: 1 reward: -0.4 (-144.4)
# piece: T position: 7 rotation: 1 reward: -84.6 (-56.0)
# piece: T position: 1 rotation: 2 reward: -29.6 (-25.199999999999996)
# Saved model to file autopilot-model.h5
# Saved weights to file autopilot-model-weights.h5
# piece: T position: 8 rotation: 3 reward: 9875.6 (-9961.0)
# piece: O position: 4 rotation: 0 reward: -0.4 (-55.4)
# piece: Z position: 6 rotation: 1 reward: -55.0 (-30.400000000000006)
# piece: J position: 0 rotation: 2 reward: 9899.6 (-10015.800000000001)
# piece: O position: 2 rotation: 0 reward: -29.2 (-55.39999999999999)
# piece: S position: 5 rotation: 0 reward: -55.4 (-114.6)
# piece: J position: 2 rotation: 3 reward: 0.0 (-170.6)
# piece: J position: 8 rotation: 0 reward: 9904.4 (-10074.6)
# piece: L position: 7 rotation: 2 reward: 0.8 (-201.60000000000002)
# piece: J position: 1 rotation: 2 reward: 9870.4 (-10015.199999999999)
# piece: Z position: 5 rotation: 1 reward: -55.0 (-115.80000000000001)
# piece: L position: 3 rotation: 1 reward: -29.6 (-141.6)
# piece: S position: 1 rotation: 0 reward: -55.4 (0.0)
# piece: O position: 7 rotation: 0 reward: -0.4 (-140.4)
# piece: O position: 4 rotation: 0 reward: -55.4 (-85.4)
# piece: J position: 0 rotation: 2 reward: -29.2 (-56.599999999999994)
# Training complete.
